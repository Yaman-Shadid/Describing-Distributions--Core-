# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Define the file path
file_path = "G:\\Github Desktop Reps\\Coding Dojo\\Describing-Distributions--Core-\\Data\\Medical_Dataset.csv"

# Load the dataset into a DataFrame named 'df'
df = pd.read_csv(file_path)

# Check the first few rows to ensure it's loaded correctly
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
# Define Features
features = ['VitD_levels', 'Doc_visits', 'TotalCharge']

for feature in features:
    plt.figure(figsize=(10, 6))
    
    # Plot histogram with KDE
    sns.histplot(df[feature], kde=True)
    
    # Mean and Median
    mean = df[feature].mean()
    median = df[feature].median()
    
    # Standard Deviation
    std = df[feature].std()
    
    # Plotting lines for mean, median, and std deviations
    plt.axvline(mean, color='red', linestyle='--', label='Mean')
    plt.axvline(median, color='green', linestyle='-', label='Median')
    plt.axvline(mean + std, color='black', linestyle='-', label='+1 std deviation')
    plt.axvline(mean - std, color='black', linestyle='-', label='-1 std deviation')
    
    # Highlighting the range between +1 and -1 std
    plt.axvspan(mean - std, mean + std, color='yellow', alpha=0.2)
    
    plt.title(f"Histogram for {feature}")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Is it Discrete or Continuous?
#
# - Continuous
#
# ## Does it have a skew? If so, which direction (+/-)
#
# - Positively skewed
#
# ## What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# - Mesokurtic
